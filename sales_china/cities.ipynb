# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns

# %%
df_china = pd.read_excel('dataset/chinese_provinces.xlsx')

df_us = pd.read_excel('dataset/us_states.xlsx')

merged_df = pd.merge(df_us, df_china, on='Rank', how='left')
merged_df = merged_df[['State', 'Province']]

# Filling NaNs with '北京市'
merged_df.fillna('北京市', inplace=True)

# %%
merged_df
# Out:
#                    State  Province
# 0             California       广东省
# 1                  Texas       山东省
# 2                Florida       河南省
# 3               New York       江苏省
# 4           Pennsylvania       四川省
# 5               Illinois       河北省
# 6                   Ohio       湖南省
# 7                Georgia       浙江省
# 8         North Carolina       安徽省
# 9               Michigan       湖北省
# 10            New Jersey   广西壮族自治区
# 11              Virginia       云南省
# 12            Washington       江西省
# 13               Arizona       辽宁省
# 14         Massachusetts       福建省
# 15             Tennessee       陕西省
# 16               Indiana      黑龙江省
# 17              Maryland       山西省
# 18              Missouri       贵州省
# 19             Wisconsin       重庆市
# 20              Colorado       吉林省
# 21             Minnesota       甘肃省
# 22        South Carolina       上海市
# 23               Alabama  新疆维吾尔自治区
# 24             Louisiana    内蒙古自治区
# 25              Kentucky       北京市
# ...

# %%
merged_df.to_excel('dataset/us_china_mapping.xlsx', index=False)
