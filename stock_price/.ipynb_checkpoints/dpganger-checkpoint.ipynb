# %%
# 1. Imports
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf  # Importing yfinance
from ydata_synthetic.synthesizers.timeseries import TimeSeriesSynthesizer
from ydata_synthetic.synthesizers import ModelParameters, TrainParameters

# 2. Data Collection
stock_symbol = "AAPL"
data = yf.download(stock_symbol, start="2010-01-01", end="2022-01-01")
df = pd.DataFrame(data)
df = df[["Close"]]
df = df.head(56)
#numerical_cols = ["Open", "High", "Low", "Close", "Adj Close", "Volume"]
numerical_cols = ["Close"]
categorical_cols = []
# Out:
# 2023-10-25 00:49:23.253409: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-25 00:49:23.315160: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-10-25 00:49:24.249832: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [*********************100%***********************]  1 of 1 completed

# %%
df
# Out:
#                Close
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714
# 2010-01-11  7.503929
# 2010-01-12  7.418571
# 2010-01-13  7.523214
# 2010-01-14  7.479643
# 2010-01-15  7.354643
# 2010-01-19  7.680000
# 2010-01-20  7.561786
# 2010-01-21  7.431071
# 2010-01-22  7.062500
# 2010-01-25  7.252500
# 2010-01-26  7.355000
# 2010-01-27  7.424286
# 2010-01-28  7.117500
# 2010-01-29  6.859286
# 2010-02-01  6.954643
# 2010-02-02  6.995000
# 2010-02-03  7.115357
# 2010-02-04  6.858929
# 2010-02-05  6.980714
# 2010-02-08  6.932857
# 2010-02-09  7.006786
# 2010-02-10  6.968571
# 2010-02-11  7.095357
# 2010-02-12  7.156429
# 2010-02-16  7.264286
# 2010-02-17  7.233929
# 2010-02-18  7.247500
# 2010-02-19  7.202500
# 2010-02-22  7.157857
# 2010-02-23  7.037857
# 2010-02-24  7.166429
# 2010-02-25  7.214286
# 2010-02-26  7.307857
# 2010-03-01  7.463929
# 2010-03-02  7.458929
# 2010-03-03  7.476071
# 2010-03-04  7.525357
# 2010-03-05  7.819643
# 2010-03-08  7.824286
# 2010-03-09  7.965000
# 2010-03-10  8.030000
# 2010-03-11  8.053571
# 2010-03-12  8.092857
# 2010-03-15  7.994286
# 2010-03-16  8.016071
# 2010-03-17  8.004286
# 2010-03-18  8.023214
# 2010-03-19  7.937500
# 2010-03-22  8.026786
# 2010-03-23  8.155714
# 2010-03-24  8.191786

# %%
# Defining model and training parameters
model_args = ModelParameters(batch_size=100,
                             lr=0.001,
                             betas=(0.2, 0.9),
                             latent_dim=20,
                             gp_lambda=2,
                             pac=1)
 
train_args = TrainParameters(epochs=400,
                             sequence_length=56,
                             sample_length=7,
                             rounds=1,
                             measurement_cols=["Close"])

extra_rows = df.shape[0] % train_args.sequence_length
if extra_rows > 0:
    df = df[:-extra_rows]

df
# Out:
#                Close
# Date
# 2010-01-04  7.643214
# 2010-01-05  7.656429
# 2010-01-06  7.534643
# 2010-01-07  7.520714
# 2010-01-08  7.570714
# 2010-01-11  7.503929
# 2010-01-12  7.418571
# 2010-01-13  7.523214
# 2010-01-14  7.479643
# 2010-01-15  7.354643
# 2010-01-19  7.680000
# 2010-01-20  7.561786
# 2010-01-21  7.431071
# 2010-01-22  7.062500
# 2010-01-25  7.252500
# 2010-01-26  7.355000
# 2010-01-27  7.424286
# 2010-01-28  7.117500
# 2010-01-29  6.859286
# 2010-02-01  6.954643
# 2010-02-02  6.995000
# 2010-02-03  7.115357
# 2010-02-04  6.858929
# 2010-02-05  6.980714
# 2010-02-08  6.932857
# 2010-02-09  7.006786
# 2010-02-10  6.968571
# 2010-02-11  7.095357
# 2010-02-12  7.156429
# 2010-02-16  7.264286
# 2010-02-17  7.233929
# 2010-02-18  7.247500
# 2010-02-19  7.202500
# 2010-02-22  7.157857
# 2010-02-23  7.037857
# 2010-02-24  7.166429
# 2010-02-25  7.214286
# 2010-02-26  7.307857
# 2010-03-01  7.463929
# 2010-03-02  7.458929
# 2010-03-03  7.476071
# 2010-03-04  7.525357
# 2010-03-05  7.819643
# 2010-03-08  7.824286
# 2010-03-09  7.965000
# 2010-03-10  8.030000
# 2010-03-11  8.053571
# 2010-03-12  8.092857
# 2010-03-15  7.994286
# 2010-03-16  8.016071
# 2010-03-17  8.004286
# 2010-03-18  8.023214
# 2010-03-19  7.937500
# 2010-03-22  8.026786
# 2010-03-23  8.155714
# 2010-03-24  8.191786

# %%
# Training the DoppelGANger synthesizer
model_dop_gan = TimeSeriesSynthesizer(modelname='doppelganger',model_parameters=model_args)
model_dop_gan.fit(df, train_args, num_cols=numerical_cols, cat_cols=categorical_cols)
 
# Generating new synthetic samples
synth_data = model_dop_gan.sample(n_samples=1)
synth_df = pd.concat(synth_data, axis=0)
# Out:
# WARNING:tensorflow:From /root/jupyter/jupyterlab/venv/lib/python3.10/site-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# /root/jupyter/jupyterlab/venv/lib/python3.10/site-packages/ydata_synthetic/synthesizers/timeseries/doppelganger/network.py:13: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   output = tf.compat.v1.layers.dense(
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /root/jupyter/jupyterlab/venv/lib/python3.10/site-packages/keras/layers/rnn/legacy_cells.py:1042: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /root/jupyter/jupyterlab/venv/lib/python3.10/site-packages/ydata_synthetic/synthesizers/timeseries/doppelganger/network.py:274: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   cell = tf.compat.v1.nn.rnn_cell.LSTMCell(
# 2023-10-25 00:49:27.044156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.049048: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.053108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.057344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.061685: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.065910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.069990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.074223: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.078373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.082760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.087050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.091401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.095820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.100367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# 2023-10-25 00:49:27.104549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator/strided_slice}}]]
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# 2023-10-25 00:49:27.872419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.877801: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.881868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.886136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.890192: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.894510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.898666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.902853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.906890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.911158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.915183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.919478: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.923624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.928023: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# 2023-10-25 00:49:27.932169: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_1/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_1/strided_slice}}]]
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# 2023-10-25 00:49:28.338301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.343138: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.347263: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.351560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.355667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.360015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.364137: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.368372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.372418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.376659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.380695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.384968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.389072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.393377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.397674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_2/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_2/strided_slice}}]]
# 2023-10-25 00:49:28.814309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.819118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.823179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.827411: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.831417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.835715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.839765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.844008: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.848058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.852260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.856266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.860470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.864614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.868899: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:28.872923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'zeros/packed/DoppelGANgerGenerator_3/strided_slice' with dtype int32
# 	 [[{{node zeros/packed/DoppelGANgerGenerator_3/strided_slice}}]]
# 2023-10-25 00:49:31.517326: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# 100%|██████████| 400/400 [00:00<00:00, 47944.49it/s]

# %%
# First 56 points of original data
original_first_56 = df.head(56)

# First 56 points of synthetic data
synthetic_first_56 = synth_df.head(56)

# Original Data
original_first_56[['Close']].plot(title='Original Data')

# Synthetic Data
synthetic_first_56[['Close']].plot(title='Synthetic Data')
plt.show()

# %%
synth_df
